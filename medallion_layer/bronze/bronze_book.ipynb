-- %%
use catalog paymentdw;

-- %%
drop schema if exists paymentdw.bronze cascade;

-- %%
create or replace table paymentdw.bronze.olist_orders
as select *, current_timestamp() as _ingestion_timestamp, 'olist_orders_dataset.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/olist_orders_dataset.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.olist_order_items
as select *, current_timestamp() as _ingestion_timestamp, 'olist_order_items_dataset.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/olist_order_items_dataset.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.olist_order_payments
as select *, current_timestamp() as _ingestion_timestamp, 'olist_order_payments_dataset.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/olist_order_payments_dataset.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.olist_customers
as select *, current_timestamp() as _ingestion_timestamp, 'olist_customers_dataset.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/olist_customers_dataset.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.olist_sellers
as select *, current_timestamp() as _ingestion_timestamp, 'olist_sellers_dataset.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/olist_sellers_dataset.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.olist_products
as select *, current_timestamp() as _ingestion_timestamp, 'olist_products_dataset.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/olist_products_dataset.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.olist_reviews
as select *, current_timestamp() as _ingestion_timestamp, 'olist_order_reviews_dataset.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/olist_order_reviews_dataset.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.olist_geolocation
as select *, current_timestamp() as _ingestion_timestamp, 'olist_geolocation_dataset.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/olist_geolocation_dataset.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.product_category_translation
as select *, current_timestamp() as _ingestion_timestamp, 'product_category_name_translation.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/product_category_name_translation.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.cards_data
as select *, current_timestamp() as _ingestion_timestamp, 'cards_data.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/cards_data.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.transactions_data
as select *, current_timestamp() as _ingestion_timestamp, 'transactions_data.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/transactions_data.csv', format => 'csv', header => 'true', inferSchema => 'true');

create or replace table paymentdw.bronze.users_data
as select *, current_timestamp() as _ingestion_timestamp, 'users_data.csv' as _source_file
from read_files('/Volumes/paymentdw/default/raw_csv/users_data.csv', format => 'csv', header => 'true', inferSchema => 'true');

-- %%
-- Should show real column names, not _c0 _c1 _c2
SELECT * FROM paymentdw.bronze.cards_data LIMIT 3;

-- %%
-- Verify all 12 tables landed with correct row counts
SELECT 'olist_orders'               AS table_name, COUNT(*) AS row_count FROM paymentdw.bronze.olist_orders
UNION ALL SELECT 'olist_order_items',               COUNT(*) FROM paymentdw.bronze.olist_order_items
UNION ALL SELECT 'olist_order_payments',            COUNT(*) FROM paymentdw.bronze.olist_order_payments
UNION ALL SELECT 'olist_customers',                 COUNT(*) FROM paymentdw.bronze.olist_customers
UNION ALL SELECT 'olist_sellers',                   COUNT(*) FROM paymentdw.bronze.olist_sellers
UNION ALL SELECT 'olist_products',                  COUNT(*) FROM paymentdw.bronze.olist_products
UNION ALL SELECT 'olist_reviews',                   COUNT(*) FROM paymentdw.bronze.olist_reviews
UNION ALL SELECT 'olist_geolocation',               COUNT(*) FROM paymentdw.bronze.olist_geolocation
UNION ALL SELECT 'product_category_translation',    COUNT(*) FROM paymentdw.bronze.product_category_translation
UNION ALL SELECT 'cards_data',                      COUNT(*) FROM paymentdw.bronze.cards_data
UNION ALL SELECT 'transactions_data',               COUNT(*) FROM paymentdw.bronze.transactions_data
UNION ALL SELECT 'users_data',                      COUNT(*) FROM paymentdw.bronze.users_data
ORDER BY table_name;
